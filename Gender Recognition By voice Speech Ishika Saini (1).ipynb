# %% [markdown]
# # Gender Recognition By Voice Speech

# %% [markdown]
# Problem statement: Create a classification model to predict the gender (male or female) based on different acoustic parameters.<br>
# 1.Test-Train data split<br>
# 2.Support Vector Machine(SVM)<br>
# 3.Desicion Tree Classifier<br>
# 4.Random Forest Classifier<br>
# 5.KNN Classifier<br>
# 6.Logistic Regression<br>
# 7.Confusion matrix and classification report<br>
# 8.Best accuracy<br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading Data

# %%
df = pd.read_csv("voice.csv")

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
df.shape
# Out:
# (3168, 21)

# %% [markdown]
# ### Different Attributes

# %%
print(df.columns)
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.info() #info about each attribute
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %% [markdown]
# Data Insights and adding label to male/female

# %%
a=df.label.value_counts()
print(a)
print("TOTAL: ",df.label.count())
# Out:
# male      1584
# female    1584
# Name: label, dtype: int64
# TOTAL:  3168

# %%
df.corr() #correlation between different input variables
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['label'] = lb.fit_transform(df['label'])
#df['label'].value_counts()
print(df)
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %% [markdown]
# ### Splitting dataset into taining set and testing set

# %%
y = df.label.values
x = df.drop(['label'],axis='columns')
from sklearn.model_selection import train_test_split                  #importing class for splitting
x_train, x_test, y_train, y_test =train_test_split(x,y,test_size=0.2,random_state =50) #20% test data, 80% train data
algo_names=[]
algo_scores=[]

# %%
x_train.shape
# Out:
# (2534, 20)

# %%
x_test.shape
# Out:
# (634, 20)

# %%
x_train.head()
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 974   0.188291  0.060757  0.196792  0.128553  0.243459  0.114906  1.924342
# 2769  0.187396  0.044700  0.185598  0.171349  0.206260  0.034911  2.454544
# 1805  0.177266  0.033878  0.175619  0.166018  0.188938  0.022920  3.261121
# 175   0.134962  0.062047  0.111388  0.088780  0.189571  0.100791  2.317095
# 1919  0.097562  0.070847  0.071001  0.038766  0.158224  0.119458  1.430850
#
#            kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 974    6.921315  0.898536  0.359334  0.117107  0.188291  0.130205  0.048096
# 2769   9.671798  0.878222  0.354332  0.174198  0.187396  0.155880  0.048534
# 1805  14.297520  0.816742  0.226999  0.164469  0.177266  0.164342  0.020833
# 175    9.072179  0.931091  0.560896  0.104794  0.134962  0.086565  0.016277
# 1919   4.652448  0.952220  0.664712  0.038555  0.097562  0.148914  0.019851
#
# ...

# %%
x_train.tail()
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 2014  0.142297  0.083138  0.169747  0.058402  0.217596  0.159194   1.963700
# 2157  0.183551  0.033172  0.187811  0.178004  0.196637  0.018634   3.361455
# 1931  0.162205  0.069786  0.182035  0.136821  0.210530  0.073709   4.105541
# 1504  0.117170  0.076995  0.108125  0.050000  0.201406  0.151406  10.649260
# 1712  0.240844  0.053585  0.256984  0.236169  0.268792  0.032623   3.203079
#
#             kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 2014    7.248161  0.955880  0.700716  0.229604  0.142297  0.178167  0.017877
# 2157   14.422563  0.785318  0.235786  0.192715  0.183551  0.177953  0.060377
# 1931   35.655663  0.930920  0.575286  0.000000  0.162205  0.149335  0.027257
# 1504  228.008040  0.944999  0.653185  0.000000  0.117170  0.111191  0.015640
# 1712   14.252101  0.824963  0.201548  0.268392  0.240844  0.225755  0.062745
#
# ...

# %% [markdown]
# ## Applying Different Models

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dec_tree = DecisionTreeClassifier(random_state = 50)
dec_tree.fit(x_train,y_train)
print("Decision tree classification score: ",dec_tree.score(x_test,y_test))           #accuracy
algo_names.append("Descision Tree")
algo_scores.append(dec_tree.score(x_test,y_test))
p1=dec_tree.predict(x_test)                                                           #predicted values
# Out:
# Decision tree classification score:  0.9511041009463722

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rand_forest = RandomForestClassifier(random_state = 50)
rand_forest.fit(x_train,y_train)
print("Random forest classification score: ",rand_forest.score(x_test,y_test))
algo_names.append("Random Forest")
algo_scores.append(rand_forest.score(x_test,y_test))
p2=rand_forest.predict(x_test)
# Out:
# Random forest classification score:  0.9747634069400631

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
svm=SVC(random_state = 50)
svm.fit(x_train,y_train)
print("SVM classification score is :{}".format(svm.score(x_test,y_test)))
algo_names.append("SVM")
algo_scores.append(svm.score(x_test,y_test))
p3=svm.predict(x_test)
# Out:
# SVM classification score is :0.6750788643533123

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
print("KNN classification score is: ",knn.score(x_test,y_test))
algo_names.append("KNN")
algo_scores.append(knn.score(x_test,y_test))
p4=knn.predict(x_test)
# Out:
# KNN classification score is:  0.7208201892744479

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(solver='liblinear')
lr.fit(x_train,y_train)
print("Logistic Regression classification score is: ",lr.score(x_test,y_test))
algo_names.append("Logistic Regression")
algo_scores.append(lr.score(x_test,y_test))
p5=lr.predict(x_test)
# Out:
# Logistic Regression classification score is:  0.9132492113564669

# %% [markdown]
# ### Classification Report and Confusion Matrix

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
report_dec_tree = classification_report(y_test,p1)                          #decision tree
print(report_dec_tree)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       324
#            1       0.95      0.95      0.95       310
#
#     accuracy                           0.95       634
#    macro avg       0.95      0.95      0.95       634
# weighted avg       0.95      0.95      0.95       634

# %%
cm1 = confusion_matrix(y_test,p1)
print('Confusion matrix for Decision Tree\n',cm1)
sns.heatmap(cm1,annot=True)
plt.show()
# Out:
# Confusion matrix for Decision Tree
#  [[308  16]
#  [ 15 295]]

# %%
report_random_forest = classification_report(y_test,p2)
print(report_random_forest)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       324
#            1       0.98      0.97      0.97       310
#
#     accuracy                           0.97       634
#    macro avg       0.97      0.97      0.97       634
# weighted avg       0.97      0.97      0.97       634

# %%
cm2 = confusion_matrix(y_test,p2)
print('Confusion matrix for Random Forest Tree\n',cm2)
sns.heatmap(cm2,annot=True)
plt.show()
# Out:
# Confusion matrix for Random Forest Tree
#  [[318   6]
#  [ 10 300]]

# %%
report_svm = classification_report(y_test,p3)
print(report_random_forest)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       324
#            1       0.98      0.97      0.97       310
#
#     accuracy                           0.97       634
#    macro avg       0.97      0.97      0.97       634
# weighted avg       0.97      0.97      0.97       634

# %%
cm3 = confusion_matrix(y_test,p3)
print('Confusion matrix for SVM\n',cm3)
sns.heatmap(cm3,annot=True)
plt.show()
# Out:
# Confusion matrix for SVM
#  [[170 154]
#  [ 52 258]]

# %%
report_knn = classification_report(y_test,p4)
print(report_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.68      0.71       324
#            1       0.70      0.76      0.73       310
#
#     accuracy                           0.72       634
#    macro avg       0.72      0.72      0.72       634
# weighted avg       0.72      0.72      0.72       634

# %%
cm4 = confusion_matrix(y_test,p4)
print('Confusion matrix for KNN\n',cm4)
sns.heatmap(cm4,annot=True)
plt.show()
# Out:
# Confusion matrix for KNN
#  [[221 103]
#  [ 74 236]]

# %%
report_lr = classification_report(y_test,p5)
print(report_lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       324
#            1       0.87      0.97      0.92       310
#
#     accuracy                           0.91       634
#    macro avg       0.92      0.91      0.91       634
# weighted avg       0.92      0.91      0.91       634

# %%
cm5 = confusion_matrix(y_test,p5)
print('Confusion matrix for Logistic Regression\n',cm5)
sns.heatmap(cm5,annot=True)
plt.show()
# Out:
# Confusion matrix for Logistic Regression
#  [[279  45]
#  [ 10 300]]

# %% [markdown]
# ## Plotting Pie charts

# %% [markdown]
# ### Decision Tree

# %%
comp1=[31.7,602.3]
l1=['predicted wrong','predicted correct']
plt.pie(comp1, labels=l1,autopct='%0.1f%%',colors=['red','pink'])
plt.title('DECISION TREE PREDICTIONS')
plt.show()

# %% [markdown]
# ### Random Forest

# %%
comp2=[12.60,621.32]
l2=['predicted wrong','predicted correct']
plt.pie(comp2,labels=l2,autopct='%0.1f%%',colors=['red','pink'])
plt.title('RANDOM FOREST')
plt.show()

# %% [markdown]
# ### SVM

# %%
comp3=[171.18,462.82]
l3=['predicted wrong','predicted correct']
plt.pie(comp3,labels=l3,autopct='%0.1f%%',colors=['red','pink'])
plt.title('SVM')
plt.show()

# %% [markdown]
# ### KNN

# %%
comp4=[145.24,488.76]
l4=['predicted wrong','predicted correct']
plt.pie(comp4,labels=l4,autopct='%0.1f%%',colors=['red','pink'])
plt.title('KNN')
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
comp5=[54.2,579.8]
l5=['predicted wrong','predicted correct']
plt.pie(comp5,labels=l5,autopct='%0.1f%%',colors=['red','pink'])
plt.title('LOGISTIC REGRESSION')
plt.show()

# %% [markdown]
# # COUNCLUSION:

# %% [markdown]
# ## Based on Precision, F1-Score, Recall Values, Prediction Pie charts, Accuracy Score and  Confusion Matrix, We can say that RANDOM FOREST CLASSIFICATION IS BEST for this problem statement where we are predicting the person's gender(Male/Female) based upon their voice signals. SUPPORT VECTOR MACHINE IS LEAST SUITABLE FOR THIS PROBLEM STATEMENT.
